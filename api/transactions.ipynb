# %%
import json

# %%
with open("transactions.json") as f:
    data_copy = json.load(f)
data_copy
# Out:
# [{'Date': '2018-09-21 00:00:00',
#   'Account': 'Card',
#   'Category': 'Other',
#   'Note': 'Bank',
#   'Amount': '4262',
#   'Type': 'Income'},
#  {'Date': '2018-09-21 00:00:00',
#   'Account': 'Card',
#   'Category': 'Other',
#   'Note': 'Start Amount',
#   'Amount': '17403',
#   'Type': 'Income'},
#  {'Date': '2018-09-21 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Other',
#   'Note': 'Aktier',
#   'Amount': '10345',
#   'Type': 'Income'},
#  {'Date': '2018-09-23 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'mcdonalds',
#   'Amount': '44',
#   'Type': 'Expense'},
#  {'Date': '2018-09-25 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '25',
#   'Type': 'Income'},
#  {'Date': '2018-09-25 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-6',
#   'Type': 'Income'},
#  {'Date': '2018-09-25 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång 21-28 augusti 2018',
#   'Amount': '116',
#   'Type': 'Income'},
#  {'Date': '2018-09-25 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': 'barnvakt 2h',
#   'Amount': '200',
#   'Type': 'Income'},
#  {'Date': '2018-09-25 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': 'barnvakt',
#   'Amount': '350',
#   'Type': 'Income'},
#  {'Date': '2018-09-25 00:00:00',
#   'Account': 'Card',
#   'Category': 'Other',
#   'Note': None,
#   'Amount': '2218',
#   'Type': 'Income'},
#  {'Date': '2018-09-25 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'monster ',
#   'Amount': '11',
#   'Type': 'Expense'},
#  {'Date': '2018-09-25 00:00:00',
#   'Account': 'Card',
#   'Category': 'Swedbank Savings',
#   'Note': 'Settlement',
#   'Amount': '4030',
#   'Type': 'Transfer-Out'},
#  {'Date': '2018-09-25 00:00:00',
#   'Account': 'Card',
#   'Category': 'Entertainment',
#   'Note': 'kortspel, betting',
#   'Amount': '20',
#   'Type': 'Expense'},
#  {'Date': '2018-09-26 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'nedgång',
#   'Amount': '-24',
#   'Type': 'Income'},
#  {'Date': '2018-09-26 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'nedgång',
#   'Amount': '-8',
#   'Type': 'Income'},
#  {'Date': '2018-09-27 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-47',
#   'Type': 'Income'},
#  {'Date': '2018-09-27 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-17',
#   'Type': 'Income'},
#  {'Date': '2018-09-27 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-14',
#   'Type': 'Income'},
#  {'Date': '2018-09-27 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': 'barnvakt 3h',
#   'Amount': '300',
#   'Type': 'Income'},
#  {'Date': '2018-09-27 00:00:00',
#   'Account': 'Paypal',
#   'Category': 'Adjustment',
#   'Note': 'Justering',
#   'Amount': '219.1',
#   'Type': 'Income'},
#  {'Date': '2018-09-28 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '-15',
#   'Type': 'Income'},
#  {'Date': '2018-09-28 00:00:00',
#   'Account': 'Gift Card',
#   'Category': 'Adjustment',
#   'Note': 'Justering',
#   'Amount': '176.4',
#   'Type': 'Income'},
#  {'Date': '2018-09-29 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Pizza hut',
#   'Amount': '95',
#   'Type': 'Expense'},
#  {'Date': '2018-09-30 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-41',
#   'Type': 'Income'},
#  {'Date': '2018-09-30 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': 'barnvakt 2h 15m',
#   'Amount': '225',
#   'Type': 'Income'},
#  {'Date': '2018-10-01 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-41',
#   'Type': 'Income'},
#  {'Date': '2018-10-01 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': 'barnvakt 7h 30m',
#   'Amount': '800',
#   'Type': 'Income'},
#  {'Date': '2018-10-03 00:00:00',
#   'Account': 'Swedbank Savings',
#   'Category': 'Work',
#   'Note': 'plocka frukt 2h 45m',
#   'Amount': '275',
#   'Type': 'Income'},
#  {'Date': '2018-10-04 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-4',
#   'Type': 'Income'},
#  {'Date': '2018-10-04 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Dricka',
#   'Amount': '20',
#   'Type': 'Expense'},
#  {'Date': '2018-10-04 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'karamel',
#   'Amount': '5',
#   'Type': 'Expense'},
#  {'Date': '2018-10-05 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-7',
#   'Type': 'Income'},
#  {'Date': '2018-10-05 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'mcdonalds',
#   'Amount': '56',
#   'Type': 'Expense'},
#  {'Date': '2018-10-07 00:00:00',
#   'Account': 'Swedbank Savings',
#   'Category': 'Study Grant',
#   'Note': 'Studiebidrag för september',
#   'Amount': '1250',
#   'Type': 'Income'},
#  {'Date': '2018-10-08 00:00:00',
#   'Account': 'Gift Card',
#   'Category': 'Other',
#   'Note': 'Steam, sålda items',
#   'Amount': '15',
#   'Type': 'Income'},
#  {'Date': '2018-10-08 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '2h 30m',
#   'Amount': '250',
#   'Type': 'Income'},
#  {'Date': '2018-10-09 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '4',
#   'Type': 'Income'},
#  {'Date': '2018-10-09 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '28',
#   'Type': 'Income'},
#  {'Date': '2018-10-10 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '32',
#   'Type': 'Income'},
#  {'Date': '2018-10-11 00:00:00',
#   'Account': 'Swedbank Savings',
#   'Category': 'Work',
#   'Note': 'plocka frukt 1h 15m',
#   'Amount': '125',
#   'Type': 'Income'},
#  {'Date': '2018-10-12 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-18',
#   'Type': 'Income'},
#  {'Date': '2018-10-13 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '2h 15m',
#   'Amount': '225',
#   'Type': 'Income'},
#  {'Date': '2018-10-15 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '30',
#   'Type': 'Income'},
#  {'Date': '2018-10-15 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Zero',
#   'Amount': '11',
#   'Type': 'Expense'},
#  {'Date': '2018-10-16 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'mcdonalds',
#   'Amount': '58',
#   'Type': 'Expense'},
#  {'Date': '2018-10-17 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '2h 30m',
#   'Amount': '275',
#   'Type': 'Income'},
#  {'Date': '2018-10-18 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-82',
#   'Type': 'Income'},
#  {'Date': '2018-10-19 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '6',
#   'Type': 'Income'},
#  {'Date': '2018-10-19 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'smörgås',
#   'Amount': '16.5',
#   'Type': 'Expense'},
#  {'Date': '2018-10-22 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '45',
#   'Type': 'Income'},
#  {'Date': '2018-10-22 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Pizza hut',
#   'Amount': '94.5',
#   'Type': 'Expense'},
#  {'Date': '2018-10-22 00:00:00',
#   'Account': 'Swedbank Savings',
#   'Category': 'Work',
#   'Note': '8h fittnes and wealth',
#   'Amount': '1381.63',
#   'Type': 'Income'},
#  {'Date': '2018-10-23 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-34',
#   'Type': 'Income'},
#  {'Date': '2018-10-23 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'starbucks plugg',
#   'Amount': '37',
#   'Type': 'Expense'},
#  {'Date': '2018-10-24 00:00:00',
#   'Account': 'Swedbank Savings',
#   'Category': 'Nordnet',
#   'Note': None,
#   'Amount': '5000',
#   'Type': 'Transfer-Out'},
#  {'Date': '2018-10-25 00:00:00',
#   'Account': 'Card',
#   'Category': 'Swedbank Savings',
#   'Note': None,
#   'Amount': '2682.78',
#   'Type': 'Transfer-Out'},
#  {'Date': '2018-10-26 00:00:00',
#   'Account': 'Card',
#   'Category': 'Swedbank Savings',
#   'Note': None,
#   'Amount': '518',
#   'Type': 'Transfer-Out'},
#  {'Date': '2018-10-28 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '15',
#   'Type': 'Income'},
#  {'Date': '2018-10-28 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '2h 15m',
#   'Amount': '250',
#   'Type': 'Income'},
#  {'Date': '2018-10-28 00:00:00',
#   'Account': 'Swedbank Savings',
#   'Category': 'Adjustment',
#   'Note': 'Justering',
#   'Amount': '208',
#   'Type': 'Income'},
#  {'Date': '2018-10-28 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'vatten',
#   'Amount': '20',
#   'Type': 'Expense'},
#  {'Date': '2018-10-29 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '8',
#   'Type': 'Income'},
#  {'Date': '2018-10-30 00:00:00',
#   'Account': 'Cash',
#   'Category': 'Other',
#   'Note': 'mcdonalds kuponger ',
#   'Amount': '240',
#   'Type': 'Income'},
#  {'Date': '2018-10-31 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '11',
#   'Type': 'Income'},
#  {'Date': '2018-10-31 00:00:00',
#   'Account': 'Swedbank Savings',
#   'Category': 'Nordnet',
#   'Note': 'aktier index fond',
#   'Amount': '3500',
#   'Type': 'Transfer-Out'},
#  {'Date': '2018-11-01 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'karamel',
#   'Amount': '5',
#   'Type': 'Expense'},
#  {'Date': '2018-11-02 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '55',
#   'Type': 'Income'},
#  {'Date': '2018-11-05 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '10',
#   'Type': 'Income'},
#  {'Date': '2018-11-06 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-135',
#   'Type': 'Income'},
#  {'Date': '2018-11-06 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'mcdonalds',
#   'Amount': '70',
#   'Type': 'Expense'},
#  {'Date': '2018-11-06 00:00:00',
#   'Account': 'Swedbank Savings',
#   'Category': 'Study Grant',
#   'Note': 'Studiebidrag för oktober',
#   'Amount': '1250',
#   'Type': 'Income'},
#  {'Date': '2018-11-07 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-90',
#   'Type': 'Income'},
#  {'Date': '2018-11-07 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-172',
#   'Type': 'Income'},
#  {'Date': '2018-11-07 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '7,5h barnvakt',
#   'Amount': '700',
#   'Type': 'Income'},
#  {'Date': '2018-11-07 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'espressohouse te',
#   'Amount': '35',
#   'Type': 'Expense'},
#  {'Date': '2018-11-07 00:00:00',
#   'Account': 'Card',
#   'Category': 'Technology',
#   'Note': 'Nya hörlurar',
#   'Amount': '241',
#   'Type': 'Expense'},
#  {'Date': '2018-11-08 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-151',
#   'Type': 'Income'},
#  {'Date': '2018-11-08 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-32',
#   'Type': 'Income'},
#  {'Date': '2018-11-08 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'mcdonalds',
#   'Amount': '58',
#   'Type': 'Expense'},
#  {'Date': '2018-11-09 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-100',
#   'Type': 'Income'},
#  {'Date': '2018-11-09 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'helvete dag, tech nedgång',
#   'Amount': '-126',
#   'Type': 'Income'},
#  {'Date': '2018-11-09 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'mcdonalds',
#   'Amount': '58',
#   'Type': 'Expense'},
#  {'Date': '2018-11-11 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-14',
#   'Type': 'Income'},
#  {'Date': '2018-11-12 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Dricka',
#   'Amount': '13',
#   'Type': 'Expense'},
#  {'Date': '2018-11-15 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '152',
#   'Type': 'Income'},
#  {'Date': '2018-11-16 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '51',
#   'Type': 'Income'},
#  {'Date': '2018-11-20 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-84',
#   'Type': 'Income'},
#  {'Date': '2018-11-20 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '57',
#   'Type': 'Income'},
#  {'Date': '2018-11-20 00:00:00',
#   'Account': 'Cash',
#   'Category': 'Food',
#   'Note': 'mcdonalds kuponger ',
#   'Amount': '80',
#   'Type': 'Expense'},
#  {'Date': '2018-11-22 00:00:00',
#   'Account': 'Card',
#   'Category': 'Other',
#   'Note': 'su',
#   'Amount': '78',
#   'Type': 'Income'},
#  {'Date': '2018-11-23 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-110',
#   'Type': 'Income'},
#  {'Date': '2018-11-23 00:00:00',
#   'Account': 'Swedbank Savings',
#   'Category': 'Adjustment',
#   'Note': 'Justering',
#   'Amount': '202.13',
#   'Type': 'Income'},
#  {'Date': '2018-11-25 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '68',
#   'Type': 'Income'},
#  {'Date': '2018-11-25 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-27',
#   'Type': 'Income'},
#  {'Date': '2018-11-25 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-236',
#   'Type': 'Income'},
#  {'Date': '2018-11-25 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': 'barnvakt 6h',
#   'Amount': '600',
#   'Type': 'Income'},
#  {'Date': '2018-11-25 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'mcdonalds',
#   'Amount': '58',
#   'Type': 'Expense'},
#  {'Date': '2018-11-25 00:00:00',
#   'Account': 'Swedbank Savings',
#   'Category': 'Nordnet',
#   'Note': None,
#   'Amount': '3000',
#   'Type': 'Transfer-Out'},
#  {'Date': '2018-11-26 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '35',
#   'Type': 'Income'},
#  {'Date': '2018-11-26 00:00:00',
#   'Account': 'Cash',
#   'Category': 'Food',
#   'Note': 'mcdonalds',
#   'Amount': '80',
#   'Type': 'Expense'},
#  {'Date': '2018-11-28 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '228',
#   'Type': 'Income'},
#  {'Date': '2018-11-28 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '230',
#   'Type': 'Income'},
#  {'Date': '2018-11-28 00:00:00',
#   'Account': 'Gift Card',
#   'Category': 'Other',
#   'Note': 'skins',
#   'Amount': '10',
#   'Type': 'Income'},
#  {'Date': '2018-11-28 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'cola',
#   'Amount': '15',
#   'Type': 'Expense'},
#  {'Date': '2018-11-30 00:00:00',
#   'Account': 'Swedbank Savings',
#   'Category': 'Other',
#   'Note': 'mag undersökning',
#   'Amount': '500',
#   'Type': 'Income'},
#  {'Date': '2018-11-30 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': 'barnvakt 2h 45m',
#   'Amount': '300',
#   'Type': 'Income'},
#  {'Date': '2018-12-03 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '135',
#   'Type': 'Income'},
#  {'Date': '2018-12-03 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '166',
#   'Type': 'Income'},
#  {'Date': '2018-12-04 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '-70',
#   'Type': 'Income'},
#  {'Date': '2018-12-05 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-42',
#   'Type': 'Income'},
#  {'Date': '2018-12-06 00:00:00',
#   'Account': 'Card',
#   'Category': 'Other',
#   'Note': 'su',
#   'Amount': '24',
#   'Type': 'Income'},
#  {'Date': '2018-12-06 00:00:00',
#   'Account': 'Gift Card',
#   'Category': 'Other',
#   'Note': 'steam ss',
#   'Amount': '6.6',
#   'Type': 'Income'},
#  {'Date': '2018-12-13 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '59',
#   'Type': 'Income'},
#  {'Date': '2018-12-13 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '2h 30m',
#   'Amount': '250',
#   'Type': 'Income'},
#  {'Date': '2018-12-13 00:00:00',
#   'Account': 'Card',
#   'Category': 'Study Grant',
#   'Note': 'Studiebidrag för november',
#   'Amount': '1250',
#   'Type': 'Income'},
#  {'Date': '2018-12-14 00:00:00',
#   'Account': 'Card',
#   'Category': 'Other',
#   'Note': 'farsdag',
#   'Amount': '100',
#   'Type': 'Expense'},
#  {'Date': '2018-12-18 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '3',
#   'Type': 'Income'},
#  {'Date': '2018-12-18 00:00:00',
#   'Account': 'Cash',
#   'Category': 'Food',
#   'Note': 'mcdonalds kuponger ',
#   'Amount': '80',
#   'Type': 'Expense'},
#  {'Date': '2018-12-20 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-121',
#   'Type': 'Income'},
#  {'Date': '2018-12-20 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'mcdonalds',
#   'Amount': '35',
#   'Type': 'Expense'},
#  {'Date': '2018-12-20 00:00:00',
#   'Account': 'Card',
#   'Category': 'Technology',
#   'Note': 'mobil skörmskydd',
#   'Amount': '170',
#   'Type': 'Expense'},
#  {'Date': '2018-12-21 00:00:00',
#   'Account': 'Card',
#   'Category': 'Other',
#   'Note': 'panta',
#   'Amount': '120',
#   'Type': 'Income'},
#  {'Date': '2018-12-24 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-145',
#   'Type': 'Income'},
#  {'Date': '2018-12-25 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-313',
#   'Type': 'Income'},
#  {'Date': '2018-12-25 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': 'barnvakt 2h 30m',
#   'Amount': '250',
#   'Type': 'Income'},
#  {'Date': '2018-12-28 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-460',
#   'Type': 'Income'},
#  {'Date': '2018-12-28 00:00:00',
#   'Account': 'Card',
#   'Category': 'Other',
#   'Note': 'mormor o farfar',
#   'Amount': '350',
#   'Type': 'Expense'},
#  {'Date': '2018-12-28 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'c',
#   'Amount': '18',
#   'Type': 'Expense'},
#  {'Date': '2019-01-01 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '2h 5m packa kuvär',
#   'Amount': '230',
#   'Type': 'Income'},
#  {'Date': '2019-01-07 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-22',
#   'Type': 'Income'},
#  {'Date': '2019-01-08 00:00:00',
#   'Account': 'Paypal',
#   'Category': 'Games',
#   'Note': 'fallout 76',
#   'Amount': '410',
#   'Type': 'Expense'},
#  {'Date': '2019-01-09 00:00:00',
#   'Account': 'Card',
#   'Category': 'Paypal',
#   'Note': None,
#   'Amount': '250',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-01-09 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Card',
#   'Note': None,
#   'Amount': '1310',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-01-11 00:00:00',
#   'Account': 'Card',
#   'Category': 'Nordnet',
#   'Note': 'Nordnet Superfond',
#   'Amount': '2500',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-01-14 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '6h 30m',
#   'Amount': '700',
#   'Type': 'Income'},
#  {'Date': '2019-01-14 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '87',
#   'Type': 'Income'},
#  {'Date': '2019-01-16 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'mcdonalds',
#   'Amount': '61',
#   'Type': 'Expense'},
#  {'Date': '2019-01-16 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '42',
#   'Type': 'Income'},
#  {'Date': '2019-01-17 00:00:00',
#   'Account': 'Card',
#   'Category': 'Swedbank Savings',
#   'Note': None,
#   'Amount': '85',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-01-18 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '323',
#   'Type': 'Income'},
#  {'Date': '2019-01-20 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': 'barvakt 8h 30m',
#   'Amount': '850',
#   'Type': 'Income'},
#  {'Date': '2019-01-20 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'mcdonalds',
#   'Amount': '61',
#   'Type': 'Expense'},
#  {'Date': '2019-01-20 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Pizza hut',
#   'Amount': '94',
#   'Type': 'Expense'},
#  {'Date': '2019-01-20 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'thai buffe',
#   'Amount': '95',
#   'Type': 'Expense'},
#  {'Date': '2019-01-20 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'kyckling sovlaki',
#   'Amount': '99',
#   'Type': 'Expense'},
#  {'Date': '2019-01-20 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Pizza hut',
#   'Amount': '94',
#   'Type': 'Expense'},
#  {'Date': '2019-01-20 00:00:00',
#   'Account': 'Card',
#   'Category': 'Present',
#   'Note': 'mormor o farfar',
#   'Amount': '1500',
#   'Type': 'Income'},
#  {'Date': '2019-01-20 00:00:00',
#   'Account': 'Card',
#   'Category': 'Study Grant',
#   'Note': 'Studiebidrag för december',
#   'Amount': '1250',
#   'Type': 'Income'},
#  {'Date': '2019-01-20 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-1017',
#   'Type': 'Income'},
#  {'Date': '2019-01-20 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '178',
#   'Type': 'Income'},
#  {'Date': '2019-01-22 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång v50',
#   'Amount': '240',
#   'Type': 'Income'},
#  {'Date': '2019-01-24 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': 'barvakt 8h',
#   'Amount': '800',
#   'Type': 'Income'},
#  {'Date': '2019-01-24 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'puzza hut',
#   'Amount': '84',
#   'Type': 'Expense'},
#  {'Date': '2019-01-25 00:00:00',
#   'Account': 'Card',
#   'Category': 'Games',
#   'Note': 'coc gems',
#   'Amount': '109',
#   'Type': 'Expense'},
#  {'Date': '2019-01-28 00:00:00',
#   'Account': 'Card',
#   'Category': 'Nordnet',
#   'Note': None,
#   'Amount': '3500',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-01-28 00:00:00',
#   'Account': 'Card',
#   'Category': 'Entertainment',
#   'Note': 'bio fanny o nate',
#   'Amount': '260',
#   'Type': 'Expense'},
#  {'Date': '2019-01-28 00:00:00',
#   'Account': 'Card',
#   'Category': 'Entertainment',
#   'Note': 'bio fanny födelsedagspresent ',
#   'Amount': '670',
#   'Type': 'Expense'},
#  {'Date': '2019-01-28 00:00:00',
#   'Account': 'Danske Bank',
#   'Category': 'Bospar',
#   'Note': None,
#   'Amount': '77025',
#   'Type': 'Income'},
#  {'Date': '2019-01-28 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång v51',
#   'Amount': '-522',
#   'Type': 'Income'},
#  {'Date': '2019-01-28 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Other',
#   'Note': 'mamma och pappa',
#   'Amount': '2000',
#   'Type': 'Income'},
#  {'Date': '2019-01-28 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Present',
#   'Note': 'mormor och anna lena',
#   'Amount': '25092',
#   'Type': 'Income'},
#  {'Date': '2019-01-29 00:00:00',
#   'Account': 'Card',
#   'Category': 'Paypal',
#   'Note': 'hemsida',
#   'Amount': '680',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-01-29 00:00:00',
#   'Account': 'Card',
#   'Category': 'Presents',
#   'Note': 'Julklapp fanny',
#   'Amount': '434',
#   'Type': 'Expense'},
#  {'Date': '2019-01-29 00:00:00',
#   'Account': 'Paypal',
#   'Category': 'Improvements',
#   'Note': 'hemsida',
#   'Amount': '707',
#   'Type': 'Expense'},
#  {'Date': '2019-01-30 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '2h 30m',
#   'Amount': '250',
#   'Type': 'Income'},
#  {'Date': '2019-01-30 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '2h 30m',
#   'Amount': '250',
#   'Type': 'Income'},
#  {'Date': '2019-01-30 00:00:00',
#   'Account': 'Card',
#   'Category': 'Other',
#   'Note': 'trisslott',
#   'Amount': '60',
#   'Type': 'Income'},
#  {'Date': '2019-01-30 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '-1255',
#   'Type': 'Income'},
#  {'Date': '2019-01-31 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Pizza hut',
#   'Amount': '95',
#   'Type': 'Expense'},
#  {'Date': '2019-01-31 00:00:00',
#   'Account': 'Card',
#   'Category': 'Study Grant',
#   'Note': 'Studiebidrag för januari',
#   'Amount': '1250',
#   'Type': 'Income'},
#  {'Date': '2019-02-01 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '2h 30m',
#   'Amount': '250',
#   'Type': 'Income'},
#  {'Date': '2019-02-01 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '2h 30m',
#   'Amount': '250',
#   'Type': 'Income'},
#  {'Date': '2019-02-01 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '200',
#   'Type': 'Income'},
#  {'Date': '2019-02-04 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': None,
#   'Amount': '90',
#   'Type': 'Expense'},
#  {'Date': '2019-02-04 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '180',
#   'Type': 'Income'},
#  {'Date': '2019-02-05 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Present',
#   'Note': 'mormor present',
#   'Amount': '60703',
#   'Type': 'Income'},
#  {'Date': '2019-02-06 00:00:00',
#   'Account': 'Card',
#   'Category': 'Other',
#   'Note': 'björn',
#   'Amount': '1000',
#   'Type': 'Income'},
#  {'Date': '2019-02-08 00:00:00',
#   'Account': 'Cash',
#   'Category': 'Other',
#   'Note': 'ullabritt',
#   'Amount': '700',
#   'Type': 'Income'},
#  {'Date': '2019-02-08 00:00:00',
#   'Account': 'Gift Card',
#   'Category': 'Other',
#   'Note': 'tina present',
#   'Amount': '300',
#   'Type': 'Income'},
#  {'Date': '2019-02-11 00:00:00',
#   'Account': 'Gift Card',
#   'Category': 'Other',
#   'Note': 'karin viktor',
#   'Amount': '400',
#   'Type': 'Income'},
#  {'Date': '2019-02-12 00:00:00',
#   'Account': 'Cash',
#   'Category': 'Other',
#   'Note': 'farfar',
#   'Amount': '600',
#   'Type': 'Income'},
#  {'Date': '2019-02-13 00:00:00',
#   'Account': 'Cash',
#   'Category': 'Card',
#   'Note': None,
#   'Amount': '1300',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-02-14 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'mcdonalds',
#   'Amount': '61',
#   'Type': 'Expense'},
#  {'Date': '2019-02-14 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'lä',
#   'Amount': '15',
#   'Type': 'Expense'},
#  {'Date': '2019-02-17 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång v4',
#   'Amount': '-59',
#   'Type': 'Income'},
#  {'Date': '2019-02-18 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': None,
#   'Amount': '850',
#   'Type': 'Income'},
#  {'Date': '2019-02-18 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Card',
#   'Note': None,
#   'Amount': '20300',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-02-18 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Nordnet',
#   'Note': None,
#   'Amount': '65500',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-02-19 00:00:00',
#   'Account': 'Card',
#   'Category': 'Swedbank Savings',
#   'Note': None,
#   'Amount': '23830',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-02-19 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '92',
#   'Type': 'Income'},
#  {'Date': '2019-03-02 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': None,
#   'Amount': '250',
#   'Type': 'Income'},
#  {'Date': '2019-03-02 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'mcdonalds',
#   'Amount': '61',
#   'Type': 'Expense'},
#  {'Date': '2019-03-02 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '88',
#   'Type': 'Income'},
#  {'Date': '2019-03-02 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Adjustment',
#   'Note': 'Justering',
#   'Amount': '104.46',
#   'Type': 'Income'},
#  {'Date': '2019-03-04 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Nordnet',
#   'Note': None,
#   'Amount': '23600',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-03-05 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': None,
#   'Amount': '150',
#   'Type': 'Income'},
#  {'Date': '2019-03-05 00:00:00',
#   'Account': 'Gift Card',
#   'Category': 'Other',
#   'Note': 'Peter Life 2017',
#   'Amount': '500',
#   'Type': 'Income'},
#  {'Date': '2019-03-05 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '321',
#   'Type': 'Income'},
#  {'Date': '2019-03-06 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Pizza hut',
#   'Amount': '95',
#   'Type': 'Expense'},
#  {'Date': '2019-03-06 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': None,
#   'Amount': '6',
#   'Type': 'Expense'},
#  {'Date': '2019-03-06 00:00:00',
#   'Account': 'Card',
#   'Category': 'Study Grant',
#   'Note': None,
#   'Amount': '1250',
#   'Type': 'Income'},
#  {'Date': '2019-03-06 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '432',
#   'Type': 'Income'},
#  {'Date': '2019-03-10 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '840',
#   'Type': 'Income'},
#  {'Date': '2019-03-10 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '315',
#   'Type': 'Income'},
#  {'Date': '2019-03-13 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '1077',
#   'Type': 'Income'},
#  {'Date': '2019-03-15 00:00:00',
#   'Account': 'Gift Card',
#   'Category': 'Games',
#   'Note': 'Csgo Kniv',
#   'Amount': '1458',
#   'Type': 'Expense'},
#  {'Date': '2019-03-17 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': None,
#   'Amount': '12',
#   'Type': 'Expense'},
#  {'Date': '2019-03-20 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': None,
#   'Amount': '250',
#   'Type': 'Income'},
#  {'Date': '2019-03-20 00:00:00',
#   'Account': 'Card',
#   'Category': 'Entertainment',
#   'Note': None,
#   'Amount': '1.99',
#   'Type': 'Expense'},
#  {'Date': '2019-03-22 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': None,
#   'Amount': '99',
#   'Type': 'Expense'},
#  {'Date': '2019-03-22 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': None,
#   'Amount': '12',
#   'Type': 'Expense'},
#  {'Date': '2019-03-25 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': None,
#   'Amount': '250',
#   'Type': 'Income'},
#  {'Date': '2019-03-27 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '1363',
#   'Type': 'Income'},
#  {'Date': '2019-04-01 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': None,
#   'Amount': '61',
#   'Type': 'Expense'},
#  {'Date': '2019-04-02 00:00:00',
#   'Account': 'Card',
#   'Category': 'Adjustment',
#   'Note': 'Justering',
#   'Amount': '1076.99',
#   'Type': 'Income'},
#  {'Date': '2019-04-02 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'pizza',
#   'Amount': '99',
#   'Type': 'Expense'},
#  {'Date': '2019-04-04 00:00:00',
#   'Account': 'Card',
#   'Category': 'Paypal',
#   'Note': 'kniv cs',
#   'Amount': '1150',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-04-07 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'go',
#   'Amount': '12',
#   'Type': 'Expense'},
#  {'Date': '2019-04-07 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '1000',
#   'Type': 'Income'},
#  {'Date': '2019-04-09 00:00:00',
#   'Account': 'Gift Card',
#   'Category': 'Paypal',
#   'Note': None,
#   'Amount': '208',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-04-11 00:00:00',
#   'Account': 'Paypal',
#   'Category': 'Gift Card',
#   'Note': 'kniv cs',
#   'Amount': '1144',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-04-23 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '2250',
#   'Type': 'Income'},
#  {'Date': '2019-04-26 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': None,
#   'Amount': '250',
#   'Type': 'Income'},
#  {'Date': '2019-04-26 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'dricka',
#   'Amount': '20',
#   'Type': 'Expense'},
#  {'Date': '2019-04-26 00:00:00',
#   'Account': 'Card',
#   'Category': 'Presents',
#   'Note': 'william',
#   'Amount': '200',
#   'Type': 'Expense'},
#  {'Date': '2019-04-26 00:00:00',
#   'Account': 'Card',
#   'Category': 'Study Grant',
#   'Note': 'Studiebidrag för Mars',
#   'Amount': '1250',
#   'Type': 'Income'},
#  {'Date': '2019-04-28 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'frasses',
#   'Amount': '82',
#   'Type': 'Expense'},
#  {'Date': '2019-04-28 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'io',
#   'Amount': '47',
#   'Type': 'Expense'},
#  {'Date': '2019-04-28 00:00:00',
#   'Account': 'Card',
#   'Category': 'Entertainment',
#   'Note': 'IO LAN',
#   'Amount': '90',
#   'Type': 'Expense'},
#  {'Date': '2019-04-29 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '5h',
#   'Amount': '500',
#   'Type': 'Income'},
#  {'Date': '2019-05-01 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': None,
#   'Amount': '250',
#   'Type': 'Income'},
#  {'Date': '2019-05-01 00:00:00',
#   'Account': 'Card',
#   'Category': 'Technology',
#   'Note': 'skärm',
#   'Amount': '3600',
#   'Type': 'Expense'},
#  {'Date': '2019-05-03 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'pizza',
#   'Amount': '89',
#   'Type': 'Expense'},
#  {'Date': '2019-05-03 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Pizza hut',
#   'Amount': '95',
#   'Type': 'Expense'},
#  {'Date': '2019-05-03 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'tee',
#   'Amount': '36',
#   'Type': 'Expense'},
#  {'Date': '2019-05-03 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Present',
#   'Note': 'mamma och pappa',
#   'Amount': '77272',
#   'Type': 'Income'},
#  {'Date': '2019-05-06 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': None,
#   'Amount': '250',
#   'Type': 'Income'},
#  {'Date': '2019-05-07 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'dricka',
#   'Amount': '25',
#   'Type': 'Expense'},
#  {'Date': '2019-05-09 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': None,
#   'Amount': '200',
#   'Type': 'Income'},
#  {'Date': '2019-05-10 00:00:00',
#   'Account': 'Card',
#   'Category': 'Study Grant',
#   'Note': 'april',
#   'Amount': '1250',
#   'Type': 'Income'},
#  {'Date': '2019-05-11 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'april',
#   'Amount': '4150',
#   'Type': 'Income'},
#  {'Date': '2019-05-17 00:00:00',
#   'Account': 'Card',
#   'Category': 'Improvements',
#   'Note': 'lä',
#   'Amount': '50',
#   'Type': 'Expense'},
#  {'Date': '2019-05-17 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'pizza',
#   'Amount': '80',
#   'Type': 'Expense'},
#  {'Date': '2019-05-17 00:00:00',
#   'Account': 'Paypal',
#   'Category': 'Games',
#   'Note': 'alts',
#   'Amount': '26',
#   'Type': 'Expense'},
#  {'Date': '2019-09-26 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': None,
#   'Amount': '250',
#   'Type': 'Income'},
#  {'Date': '2019-09-26 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'pizza hut',
#   'Amount': '95',
#   'Type': 'Expense'},
#  {'Date': '2019-09-26 00:00:00',
#   'Account': 'Card',
#   'Category': 'Other',
#   'Note': 'bio presentkort',
#   'Amount': '450',
#   'Type': 'Income'},
#  {'Date': '2019-09-26 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'bio snacks',
#   'Amount': '52',
#   'Type': 'Expense'},
#  {'Date': '2019-09-26 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': None,
#   'Amount': '10',
#   'Type': 'Expense'},
#  {'Date': '2019-09-26 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'c o c',
#   'Amount': '17',
#   'Type': 'Expense'},
#  {'Date': '2019-09-26 00:00:00',
#   'Account': 'Card',
#   'Category': 'Entertainment',
#   'Note': 'Bio End Game',
#   'Amount': '225',
#   'Type': 'Expense'},
#  {'Date': '2019-09-26 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Adjustment',
#   'Note': 'Justering',
#   'Amount': '0.71',
#   'Type': 'Income'},
#  {'Date': '2019-09-27 00:00:00',
#   'Account': 'Card',
#   'Category': 'Improvements',
#   'Note': 'tee',
#   'Amount': '18',
#   'Type': 'Expense'},
#  {'Date': '2019-09-27 00:00:00',
#   'Account': 'Card',
#   'Category': 'Study Grant',
#   'Note': 'maj',
#   'Amount': '1250',
#   'Type': 'Income'},
#  {'Date': '2019-09-27 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier nedgång',
#   'Amount': '-200',
#   'Type': 'Income'},
#  {'Date': '2019-09-28 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'monster ',
#   'Amount': '11',
#   'Type': 'Expense'},
#  {'Date': '2019-09-30 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'pizza hut',
#   'Amount': '85',
#   'Type': 'Expense'},
#  {'Date': '2019-09-30 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'dricka',
#   'Amount': '22',
#   'Type': 'Expense'},
#  {'Date': '2019-10-01 00:00:00',
#   'Account': 'Card',
#   'Category': 'Improvements',
#   'Note': 'espressohouse te',
#   'Amount': '36',
#   'Type': 'Expense'},
#  {'Date': '2019-10-02 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'milkshake ',
#   'Amount': '25',
#   'Type': 'Expense'},
#  {'Date': '2019-10-04 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '2h',
#   'Amount': '200',
#   'Type': 'Income'},
#  {'Date': '2019-10-04 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'monster ',
#   'Amount': '11',
#   'Type': 'Expense'},
#  {'Date': '2019-10-04 00:00:00',
#   'Account': 'Card',
#   'Category': 'Games',
#   'Note': 'lineage 2 revolution',
#   'Amount': '109',
#   'Type': 'Expense'},
#  {'Date': '2019-10-11 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': None,
#   'Amount': '250',
#   'Type': 'Income'},
#  {'Date': '2019-10-11 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': 'mormor',
#   'Amount': '100',
#   'Type': 'Income'},
#  {'Date': '2019-10-11 00:00:00',
#   'Account': 'Card',
#   'Category': 'Adjustment',
#   'Note': 'Justering',
#   'Amount': '18',
#   'Type': 'Income'},
#  {'Date': '2019-10-11 00:00:00',
#   'Account': 'Card',
#   'Category': 'Nordnet',
#   'Note': None,
#   'Amount': '2141',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-10-14 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Nordnet',
#   'Note': None,
#   'Amount': '775',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-10-15 00:00:00',
#   'Account': 'Card',
#   'Category': 'Nordnet',
#   'Note': None,
#   'Amount': '1000',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-10-17 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'Justering',
#   'Amount': '9553',
#   'Type': 'Income'},
#  {'Date': '2019-10-18 00:00:00',
#   'Account': 'Gift Card',
#   'Category': 'Adjustment',
#   'Note': 'Juustering',
#   'Amount': '456',
#   'Type': 'Income'},
#  {'Date': '2019-10-22 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '300',
#   'Type': 'Income'},
#  {'Date': '2019-10-25 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'monster',
#   'Amount': '15',
#   'Type': 'Expense'},
#  {'Date': '2019-10-29 00:00:00',
#   'Account': 'Card',
#   'Category': 'Paypal',
#   'Note': None,
#   'Amount': '330',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-11-01 00:00:00',
#   'Account': 'Card',
#   'Category': 'Presents',
#   'Note': 'samuel ',
#   'Amount': '250',
#   'Type': 'Expense'},
#  {'Date': '2019-11-01 00:00:00',
#   'Account': 'Paypal',
#   'Category': 'Adjustment',
#   'Note': 'Justering Paypal',
#   'Amount': '25.92',
#   'Type': 'Income'},
#  {'Date': '2019-11-01 00:00:00',
#   'Account': 'Paypal',
#   'Category': 'Games',
#   'Note': 'monster hunter world',
#   'Amount': '430',
#   'Type': 'Expense'},
#  {'Date': '2019-11-05 00:00:00',
#   'Account': 'Card',
#   'Category': 'Study Grant',
#   'Note': None,
#   'Amount': '1250',
#   'Type': 'Income'},
#  {'Date': '2019-11-05 00:00:00',
#   'Account': 'Card',
#   'Category': 'Technology',
#   'Note': 'mobil skörmskydd',
#   'Amount': '400',
#   'Type': 'Expense'},
#  {'Date': '2019-11-06 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'aktier uppgång',
#   'Amount': '1400',
#   'Type': 'Income'},
#  {'Date': '2019-11-07 00:00:00',
#   'Account': 'Paypal',
#   'Category': 'Adjustment',
#   'Note': 'Justering Paypal',
#   'Amount': '81.86',
#   'Type': 'Income'},
#  {'Date': '2019-11-10 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': None,
#   'Amount': '250',
#   'Type': 'Income'},
#  {'Date': '2019-11-10 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': None,
#   'Amount': '15',
#   'Type': 'Expense'},
#  {'Date': '2019-11-10 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'kanelbulle o monster',
#   'Amount': '16',
#   'Type': 'Expense'},
#  {'Date': '2019-11-10 00:00:00',
#   'Account': 'Card',
#   'Category': 'Entertainment',
#   'Note': 'lyxfrukost krysning',
#   'Amount': '60',
#   'Type': 'Expense'},
#  {'Date': '2019-11-11 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': None,
#   'Amount': '11',
#   'Type': 'Expense'},
#  {'Date': '2019-11-12 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': 'natt',
#   'Amount': '900',
#   'Type': 'Income'},
#  {'Date': '2019-11-12 00:00:00',
#   'Account': 'Card',
#   'Category': 'Study Grant',
#   'Note': 'Studiebidrag för oktober',
#   'Amount': '1250',
#   'Type': 'Income'},
#  {'Date': '2019-11-12 00:00:00',
#   'Account': 'Card',
#   'Category': 'Entertainment',
#   'Note': 'Kryssa ',
#   'Amount': '50',
#   'Type': 'Expense'},
#  {'Date': '2019-11-12 00:00:00',
#   'Account': 'Card',
#   'Category': 'Entertainment',
#   'Note': 'Kryssa ',
#   'Amount': '1472.79',
#   'Type': 'Expense'},
#  {'Date': '2019-11-14 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'monster',
#   'Amount': '11',
#   'Type': 'Expense'},
#  {'Date': '2019-11-14 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': None,
#   'Amount': '11',
#   'Type': 'Expense'},
#  {'Date': '2019-11-20 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'monster',
#   'Amount': '23',
#   'Type': 'Expense'},
#  {'Date': '2019-11-21 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'cola',
#   'Amount': '15',
#   'Type': 'Expense'},
#  {'Date': '2019-11-24 00:00:00',
#   'Account': 'Card',
#   'Category': 'Adjustment',
#   'Note': 'Justering Oktober',
#   'Amount': '761',
#   'Type': 'Income'},
#  {'Date': '2019-11-24 00:00:00',
#   'Account': 'Gift Card',
#   'Category': 'Improvements',
#   'Note': 'Protein Pulver, vattenflaska',
#   'Amount': '221',
#   'Type': 'Expense'},
#  {'Date': '2019-11-24 00:00:00',
#   'Account': 'Gift Card',
#   'Category': 'Games',
#   'Note': 'Kniv sold',
#   'Amount': '142',
#   'Type': 'Expense'},
#  {'Date': '2019-11-24 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '3000',
#   'Type': 'Income'},
#  {'Date': '2019-11-25 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'pizza Vedungen',
#   'Amount': '89',
#   'Type': 'Expense'},
#  {'Date': '2019-11-28 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '1h',
#   'Amount': '100',
#   'Type': 'Income'},
#  {'Date': '2019-11-28 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '1000',
#   'Type': 'Income'},
#  {'Date': '2019-11-29 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '3.5h',
#   'Amount': '450',
#   'Type': 'Income'},
#  {'Date': '2019-11-30 00:00:00',
#   'Account': 'Card',
#   'Category': 'Paypal',
#   'Note': None,
#   'Amount': '700',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-11-30 00:00:00',
#   'Account': 'Card',
#   'Category': 'Study Grant',
#   'Note': 'Studiebidrag för november',
#   'Amount': '1250',
#   'Type': 'Income'},
#  {'Date': '2019-11-30 00:00:00',
#   'Account': 'Cash',
#   'Category': 'Work',
#   'Note': 'byta däck',
#   'Amount': '100',
#   'Type': 'Income'},
#  {'Date': '2019-11-30 00:00:00',
#   'Account': 'Paypal',
#   'Category': 'Games',
#   'Note': 'Cod Modern Warfare',
#   'Amount': '572.18',
#   'Type': 'Expense'},
#  {'Date': '2019-12-04 00:00:00',
#   'Account': 'Cash',
#   'Category': 'Other',
#   'Note': None,
#   'Amount': '20',
#   'Type': 'Income'},
#  {'Date': '2019-12-04 00:00:00',
#   'Account': 'Cash',
#   'Category': 'Card',
#   'Note': 'överföring',
#   'Amount': '105',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-12-04 00:00:00',
#   'Account': 'Cash',
#   'Category': 'Food',
#   'Note': 'monster',
#   'Amount': '15',
#   'Type': 'Expense'},
#  {'Date': '2019-12-04 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '1000',
#   'Type': 'Income'},
#  {'Date': '2019-12-05 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'monster',
#   'Amount': '11',
#   'Type': 'Expense'},
#  {'Date': '2019-12-05 00:00:00',
#   'Account': 'Card',
#   'Category': 'Technology',
#   'Note': 'Nya hörlurar Boss',
#   'Amount': '299',
#   'Type': 'Expense'},
#  {'Date': '2019-12-06 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '6h 30m',
#   'Amount': '700',
#   'Type': 'Income'},
#  {'Date': '2019-12-06 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'cola',
#   'Amount': '18',
#   'Type': 'Expense'},
#  {'Date': '2019-12-09 00:00:00',
#   'Account': 'Card',
#   'Category': 'Adjustment',
#   'Note': None,
#   'Amount': '-3119',
#   'Type': 'Income'},
#  {'Date': '2019-12-11 00:00:00',
#   'Account': 'Card',
#   'Category': 'Adjustment',
#   'Note': 'Justering',
#   'Amount': '-1250',
#   'Type': 'Income'},
#  {'Date': '2019-12-11 00:00:00',
#   'Account': 'Card',
#   'Category': 'Presents',
#   'Note': 'mamma och pappa present',
#   'Amount': '916',
#   'Type': 'Expense'},
#  {'Date': '2019-12-12 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': 'postnord arkivering ',
#   'Amount': '1490',
#   'Type': 'Income'},
#  {'Date': '2019-12-13 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'mcdonalds',
#   'Amount': '79',
#   'Type': 'Expense'},
#  {'Date': '2019-12-16 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'monster',
#   'Amount': '11',
#   'Type': 'Expense'},
#  {'Date': '2019-12-16 00:00:00',
#   'Account': 'Card',
#   'Category': 'Technology',
#   'Note': 'Dator och data väska',
#   'Amount': '4376.6',
#   'Type': 'Expense'},
#  {'Date': '2019-12-17 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': 'barnvakt',
#   'Amount': '200',
#   'Type': 'Income'},
#  {'Date': '2019-12-17 00:00:00',
#   'Account': 'Paypal',
#   'Category': 'Card',
#   'Note': None,
#   'Amount': '120',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-12-19 00:00:00',
#   'Account': 'Card',
#   'Category': 'Study Grant',
#   'Note': 'Studiebidrag för december',
#   'Amount': '1250',
#   'Type': 'Income'},
#  {'Date': '2019-12-19 00:00:00',
#   'Account': 'Nordnet',
#   'Category': 'Card',
#   'Note': 'överföring',
#   'Amount': '10956',
#   'Type': 'Transfer-Out'},
#  {'Date': '2019-12-19 00:00:00',
#   'Account': 'Paypal',
#   'Category': 'Games',
#   'Note': 'Csgo Cases',
#   'Amount': '235.7',
#   'Type': 'Expense'},
#  {'Date': '2019-12-20 00:00:00',
#   'Account': 'Card',
#   'Category': 'Work',
#   'Note': '4h',
#   'Amount': '400',
#   'Type': 'Income'},
#  {'Date': '2019-12-20 00:00:00',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Fullkort, grekisk + Mcdonalds',
#   'Amount': '115',
#   'Type': 'Expense'},
#  {'Date': '2019-12-20 00:00:00',
#   'Account': 'Card',
#   'Category': 'Games',
#   'Note': 'Red Dead 2 Redemption',
#   'Amount': '307',
#   'Type': 'Expense'},
#  {'Date': '2019-12-21 00:00:00',
#   'Account': 'Gift Card',
#   'Category': 'Improvements',
#   'Note': 'Presentkort',
# ...
#   'Account': 'Card',
#   'Category': 'Technology',
#   'Note': 'Amazon Black friday',
#   'Amount': '593.58',
#   'Type': 'Expense'},
#  {'Date': '2021-11-27 23:14:38',
#   'Account': 'Gift Card',
#   'Category': 'Technology',
#   'Note': 'Skärm',
#   'Amount': '201',
#   'Type': 'Expense'},
#  {'Date': '2021-11-27 23:14:51',
#   'Account': 'Card',
#   'Category': 'Technology',
#   'Note': 'Skärm',
#   'Amount': '2589',
#   'Type': 'Expense'},
#  {'Date': '2021-11-29 09:56:45',
#   'Account': 'Card',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '8240',
#   'Type': 'Income'},
#  {'Date': '2021-11-29 18:06:59',
#   'Account': 'Card',
#   'Category': 'SL',
#   'Note': 'Sl',
#   'Amount': '50',
#   'Type': 'Expense'},
#  {'Date': '2021-11-29 18:07:07',
#   'Account': 'Card',
#   'Category': 'Entertainment',
#   'Note': 'Bio',
#   'Amount': '35',
#   'Type': 'Expense'},
#  {'Date': '2021-12-01 06:15:35',
#   'Account': 'Card',
#   'Category': 'Technology',
#   'Note': 'Samsung s21 Ultra',
#   'Amount': '400',
#   'Type': 'Expense'},
#  {'Date': '2021-12-01 06:16:49',
#   'Account': 'Card',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '-8788',
#   'Type': 'Income'},
#  {'Date': '2021-12-01 06:22:46',
#   'Account': 'Danske Bank',
#   'Category': 'Bospar',
#   'Note': 'Difference',
#   'Amount': '1500',
#   'Type': 'Income'},
#  {'Date': '2021-12-01 10:45:36',
#   'Account': 'Card',
#   'Category': 'Games',
#   'Note': 'Uno',
#   'Amount': '40.95',
#   'Type': 'Expense'},
#  {'Date': '2021-12-01 10:48:17',
#   'Account': 'Card',
#   'Category': 'Entertainment',
#   'Note': 'Spiderman ',
#   'Amount': '229',
#   'Type': 'Expense'},
#  {'Date': '2021-12-01 18:48:03',
#   'Account': 'Card',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '6458',
#   'Type': 'Income'},
#  {'Date': '2021-12-06 08:37:01',
#   'Account': 'Card',
#   'Category': 'SL',
#   'Note': 'Sl',
#   'Amount': '50',
#   'Type': 'Expense'},
#  {'Date': '2021-12-06 19:30:07',
#   'Account': 'Card',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '-18350',
#   'Type': 'Income'},
#  {'Date': '2021-12-07 08:30:03',
#   'Account': 'Card',
#   'Category': 'SL',
#   'Note': 'Sl',
#   'Amount': '50',
#   'Type': 'Expense'},
#  {'Date': '2021-12-07 18:09:23',
#   'Account': 'Card',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '18847',
#   'Type': 'Income'},
#  {'Date': '2021-12-07 20:43:40',
#   'Account': 'Card',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '3647',
#   'Type': 'Income'},
#  {'Date': '2021-12-18 15:58:42',
#   'Account': 'Card',
#   'Category': 'Entertainment',
#   'Note': 'Silja line',
#   'Amount': '1704',
#   'Type': 'Expense'},
#  {'Date': '2021-12-18 16:01:06',
#   'Account': 'Card',
#   'Category': 'Presents',
#   'Note': 'Peter Champagne',
#   'Amount': '231',
#   'Type': 'Expense'},
#  {'Date': '2021-12-18 19:05:35',
#   'Account': 'Card',
#   'Category': 'Entertainment',
#   'Note': 'Uber',
#   'Amount': '95',
#   'Type': 'Expense'},
#  {'Date': '2021-12-20 17:15:18',
#   'Account': 'Card',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '-25892',
#   'Type': 'Income'},
#  {'Date': '2021-12-21 12:23:31',
#   'Account': 'Card',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '6267',
#   'Type': 'Income'},
#  {'Date': '2021-12-21 18:14:53',
#   'Account': 'Card',
#   'Category': 'Rent',
#   'Note': None,
#   'Amount': '2250',
#   'Type': 'Expense'},
#  {'Date': '2021-12-22 14:32:59',
#   'Account': 'Card',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '5804',
#   'Type': 'Income'},
#  {'Date': '2021-12-22 19:46:07',
#   'Account': 'Card',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '3740',
#   'Type': 'Income'},
#  {'Date': '2021-12-23 06:14:43',
#   'Account': 'Card',
#   'Category': 'Study Grant',
#   'Note': 'Studiebidrag för December',
#   'Amount': '11008',
#   'Type': 'Income'},
#  {'Date': '2021-12-23 10:22:17',
#   'Account': 'Card',
#   'Category': 'Nordnet',
#   'Note': None,
#   'Amount': '3700',
#   'Type': 'Transfer-Out'},
#  {'Date': '2021-12-23 10:22:56',
#   'Account': 'Card',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '5105',
#   'Type': 'Income'},
#  {'Date': '2021-12-24 10:23:31',
#   'Account': 'Card',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '2480',
#   'Type': 'Income'},
#  {'Date': '2021-12-25 08:19:35',
#   'Account': 'Card',
#   'Category': 'Other',
#   'Note': 'Presenter',
#   'Amount': '2000',
#   'Type': 'Income'},
#  {'Date': '2021-12-27 16:14:43',
#   'Account': 'Card',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '5639',
#   'Type': 'Income'},
#  {'Date': '2021-12-31 14:38:55',
#   'Account': 'Gift Card',
#   'Category': 'Other',
#   'Note': 'Björn Superpresentkort 3år',
#   'Amount': '300',
#   'Type': 'Income'},
#  {'Date': '2022-01-03 16:00:31',
#   'Account': 'Card',
#   'Category': 'Study Grant',
#   'Note': 'Januari',
#   'Amount': '16482',
#   'Type': 'Income'},
#  {'Date': '2022-01-03 16:00:44',
#   'Account': 'Card',
#   'Category': 'Rent',
#   'Note': None,
#   'Amount': '3000',
#   'Type': 'Expense'},
#  {'Date': '2022-01-04 05:56:41',
#   'Account': 'Card',
#   'Category': 'Technology',
#   'Note': 'Samaung s21 ultra',
#   'Amount': '400',
#   'Type': 'Expense'},
#  {'Date': '2022-01-04 10:39:01',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '1546',
#   'Type': 'Income'},
#  {'Date': '2022-01-04 13:22:06',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '2416',
#   'Type': 'Income'},
#  {'Date': '2022-01-04 13:42:33',
#   'Account': 'Card',
#   'Category': 'Presents',
#   'Note': 'Mormor julklapp mat',
#   'Amount': '60',
#   'Type': 'Expense'},
#  {'Date': '2022-01-04 13:42:44',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Åkermyntan mormor',
#   'Amount': '110',
#   'Type': 'Expense'},
#  {'Date': '2022-01-04 14:58:31',
#   'Account': 'Paypal',
#   'Category': 'Games',
#   'Note': 'Difference',
#   'Amount': '672',
#   'Type': 'Expense'},
#  {'Date': '2022-01-06 07:26:24',
#   'Account': 'Card',
#   'Category': 'Games',
#   'Note': 'Clash of clans',
#   'Amount': '59',
#   'Type': 'Expense'},
#  {'Date': '2022-01-07 12:21:19',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '-23369',
#   'Type': 'Income'},
#  {'Date': '2022-01-07 21:07:57',
#   'Account': 'Card',
#   'Category': 'Technology',
#   'Note': 'Steam deck',
#   'Amount': '41.05',
#   'Type': 'Expense'},
#  {'Date': '2022-01-15 08:06:10',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '-19469',
#   'Type': 'Income'},
#  {'Date': '2022-01-18 16:36:28',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Åkermyntan',
#   'Amount': '110',
#   'Type': 'Expense'},
#  {'Date': '2022-01-18 16:36:35',
#   'Account': 'Card',
#   'Category': 'Improvements',
#   'Note': 'Blocket',
#   'Amount': '15',
#   'Type': 'Expense'},
#  {'Date': '2022-01-19 12:42:14',
#   'Account': 'Card',
#   'Category': 'Investment',
#   'Note': 'Gaming Laptop',
#   'Amount': '3500',
#   'Type': 'Income'},
#  {'Date': '2022-01-20 17:28:13',
#   'Account': 'Card',
#   'Category': 'Presents',
#   'Note': 'Åkermyntan mormor',
#   'Amount': '55',
#   'Type': 'Expense'},
#  {'Date': '2022-01-20 20:08:34',
#   'Account': 'Card',
#   'Category': 'Presents',
#   'Note': 'Pappa middah',
#   'Amount': '562',
#   'Type': 'Expense'},
#  {'Date': '2022-01-21 09:58:50',
#   'Account': 'Card',
#   'Category': 'Nordnet',
#   'Note': None,
#   'Amount': '20000',
#   'Type': 'Transfer-Out'},
#  {'Date': '2022-01-21 09:59:22',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '-13641',
#   'Type': 'Income'},
#  {'Date': '2022-01-23 13:38:50',
#   'Account': 'Card',
#   'Category': 'Technology',
#   'Note': 'Samsung s21 Ultra Sista',
#   'Amount': '6500',
#   'Type': 'Expense'},
#  {'Date': '2022-01-24 16:25:10',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '-22509',
#   'Type': 'Income'},
#  {'Date': '2022-01-26 16:06:42',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '13337',
#   'Type': 'Income'},
#  {'Date': '2022-02-01 14:00:54',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '16324',
#   'Type': 'Income'},
#  {'Date': '2022-02-01 20:35:50',
#   'Account': 'Card',
#   'Category': 'Study Grant',
#   'Note': 'Februari',
#   'Amount': '11088',
#   'Type': 'Income'},
#  {'Date': '2022-02-01 20:37:02',
#   'Account': 'Card',
#   'Category': 'Rent',
#   'Note': None,
#   'Amount': '3000',
#   'Type': 'Expense'},
#  {'Date': '2022-02-02 14:33:23',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '4327',
#   'Type': 'Income'},
#  {'Date': '2022-02-09 18:41:18',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': 'Difference',
#   'Amount': '-7549',
#   'Type': 'Income'},
#  {'Date': '2022-02-11 11:15:34',
#   'Account': 'Card',
#   'Category': 'SL',
#   'Note': None,
#   'Amount': '52',
#   'Type': 'Expense'},
#  {'Date': '2022-02-11 11:15:51',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': None,
#   'Amount': '105',
#   'Type': 'Expense'},
#  {'Date': '2022-02-11 11:15:58',
#   'Account': 'Card',
#   'Category': 'Entertainment',
#   'Note': None,
#   'Amount': '483',
#   'Type': 'Expense'},
#  {'Date': '2022-02-23 16:34:22',
#   'Account': 'Card',
#   'Category': 'Other',
#   'Note': 'Använda biokort',
#   'Amount': '531',
#   'Type': 'Income'},
#  {'Date': '2022-03-02 21:13:09',
#   'Account': 'Card',
#   'Category': 'Rent',
#   'Note': None,
#   'Amount': '3000',
#   'Type': 'Expense'},
#  {'Date': '2022-03-02 21:14:10',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '5691',
#   'Type': 'Income'},
#  {'Date': '2022-03-03 08:54:17',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Thai Mall of Scandinavia',
#   'Amount': '135',
#   'Type': 'Expense'},
#  {'Date': '2022-03-05 13:35:02',
#   'Account': 'Card',
#   'Category': 'Games',
#   'Note': 'Random Dice',
#   'Amount': '44',
#   'Type': 'Expense'},
#  {'Date': '2022-03-08 19:34:20',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Cola',
#   'Amount': '15',
#   'Type': 'Expense'},
#  {'Date': '2022-03-09 12:32:18',
#   'Account': 'Danske Bank',
#   'Category': 'Bospar',
#   'Note': None,
#   'Amount': '1031.57',
#   'Type': 'Income'},
#  {'Date': '2022-03-09 12:34:46',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '-18688',
#   'Type': 'Income'},
#  {'Date': '2022-03-12 08:38:45',
#   'Account': 'Card',
#   'Category': 'Games',
#   'Note': 'Random Dice',
#   'Amount': '29',
#   'Type': 'Expense'},
#  {'Date': '2022-03-12 15:59:47',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '-10360',
#   'Type': 'Income'},
#  {'Date': '2022-03-12 16:16:03',
#   'Account': 'Card',
#   'Category': 'Technology',
#   'Note': 'Screen Protector ',
#   'Amount': '82',
#   'Type': 'Expense'},
#  {'Date': '2022-03-13 19:24:56',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Max',
#   'Amount': '141',
#   'Type': 'Expense'},
#  {'Date': '2022-03-13 21:15:21',
#   'Account': 'Card',
#   'Category': 'Entertainment',
#   'Note': 'Bodaborg + Bensin',
#   'Amount': '330',
#   'Type': 'Expense'},
#  {'Date': '2022-03-13 21:15:48',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Taco buffe',
#   'Amount': '95',
#   'Type': 'Expense'},
#  {'Date': '2022-03-18 17:30:54',
#   'Account': 'Card',
#   'Category': 'SL',
#   'Note': None,
#   'Amount': '50',
#   'Type': 'Expense'},
#  {'Date': '2022-03-18 17:32:44',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Max',
#   'Amount': '79',
#   'Type': 'Expense'},
#  {'Date': '2022-03-18 21:25:45',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '16475',
#   'Type': 'Income'},
#  {'Date': '2022-03-20 19:02:32',
#   'Account': 'Card',
#   'Category': 'Tax',
#   'Note': 'Private Company',
#   'Amount': '265',
#   'Type': 'Expense'},
#  {'Date': '2022-03-21 10:45:17',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '3463',
#   'Type': 'Income'},
#  {'Date': '2022-03-21 13:05:41',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'grekiska',
#   'Amount': '115',
#   'Type': 'Expense'},
#  {'Date': '2022-03-21 17:40:02',
#   'Account': 'Card',
#   'Category': 'SL',
#   'Note': None,
#   'Amount': '78',
#   'Type': 'Expense'},
#  {'Date': '2022-03-22 11:47:24',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '6203',
#   'Type': 'Income'},
#  {'Date': '2022-03-22 19:41:33',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '4516',
#   'Type': 'Income'},
#  {'Date': '2022-03-23 09:15:12',
#   'Account': 'Card',
#   'Category': 'SL',
#   'Note': None,
#   'Amount': '25',
#   'Type': 'Expense'},
#  {'Date': '2022-03-24 08:14:03',
#   'Account': 'Card',
#   'Category': 'SL',
#   'Note': None,
#   'Amount': '52',
#   'Type': 'Expense'},
#  {'Date': '2022-03-25 08:02:29',
#   'Account': 'Card',
#   'Category': 'SL',
#   'Note': None,
#   'Amount': '52',
#   'Type': 'Expense'},
#  {'Date': '2022-03-25 14:00:04',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '1809',
#   'Type': 'Income'},
#  {'Date': '2022-03-25 14:30:16',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Max',
#   'Amount': '84',
#   'Type': 'Expense'},
#  {'Date': '2022-03-25 21:12:57',
#   'Account': 'Card',
#   'Category': 'Study Grant',
#   'Note': None,
#   'Amount': '11088',
#   'Type': 'Income'},
#  {'Date': '2022-03-29 08:20:56',
#   'Account': 'Card',
#   'Category': 'SL',
#   'Note': None,
#   'Amount': '52',
#   'Type': 'Expense'},
#  {'Date': '2022-03-30 10:05:07',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '8473',
#   'Type': 'Income'},
#  {'Date': '2022-03-31 00:00:00',
#   'Account': 'Danske Bank',
#   'Category': 'Bospar',
#   'Note': None,
#   'Amount': '3175',
#   'Type': 'Income'},
#  {'Date': '2022-04-01 07:47:05',
#   'Account': 'Card',
#   'Category': 'Entertainment',
#   'Note': 'Alcohol',
#   'Amount': '423',
#   'Type': 'Expense'},
#  {'Date': '2022-04-01 11:40:58',
#   'Account': 'Card',
#   'Category': 'SL',
#   'Note': None,
#   'Amount': '52',
#   'Type': 'Expense'},
#  {'Date': '2022-04-01 11:41:08',
#   'Account': 'Card',
#   'Category': 'Rent',
#   'Note': None,
#   'Amount': '3000',
#   'Type': 'Expense'},
#  {'Date': '2022-04-01 12:45:07',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Pizza',
#   'Amount': '130',
#   'Type': 'Expense'},
#  {'Date': '2022-04-04 14:31:05',
#   'Account': 'Card',
#   'Category': 'SL',
#   'Note': None,
#   'Amount': '26',
#   'Type': 'Expense'},
#  {'Date': '2022-04-07 14:07:58',
#   'Account': 'Card',
#   'Category': 'SL',
#   'Note': None,
#   'Amount': '26',
#   'Type': 'Expense'},
#  {'Date': '2022-04-07 20:01:30',
#   'Account': 'Card',
#   'Category': 'Presents',
#   'Note': 'Dad birthday flowers',
#   'Amount': '43',
#   'Type': 'Expense'},
#  {'Date': '2022-04-08 08:35:27',
#   'Account': 'Card',
#   'Category': 'SL',
#   'Note': None,
#   'Amount': '26',
#   'Type': 'Expense'},
#  {'Date': '2022-04-08 12:34:16',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Greek',
#   'Amount': '115',
#   'Type': 'Expense'},
#  {'Date': '2022-04-11 11:39:35',
#   'Account': 'Card',
#   'Category': 'SL',
#   'Note': None,
#   'Amount': '26',
#   'Type': 'Expense'},
#  {'Date': '2022-04-13 18:30:59',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '-23955',
#   'Type': 'Income'},
#  {'Date': '2022-04-14 07:05:19',
#   'Account': 'Card',
#   'Category': 'SL',
#   'Note': None,
#   'Amount': '52',
#   'Type': 'Expense'},
#  {'Date': '2022-04-14 14:51:17',
#   'Account': 'Card',
#   'Category': 'Food',
#   'Note': 'Kebab',
#   'Amount': '115',
#   'Type': 'Expense'},
#  {'Date': '2022-04-14 15:56:24',
#   'Account': 'Card',
#   'Category': 'Presents',
#   'Note': 'Flowers',
#   'Amount': '70',
#   'Type': 'Expense'},
#  {'Date': '2022-04-18 12:43:31',
#   'Account': 'Nordnet',
#   'Category': 'Investment',
#   'Note': None,
#   'Amount': '1068',
#   'Type': 'Income'},
#  {'Date': '2022-04-19 14:05:17',
#   'Account': 'Card',
#   'Category': 'Games',
#   'Note': 'Random Dice',
#   'Amount': '75',
#   'Type': 'Expense'},
#  {'Date': '2022-04-20 17:05:17',
#   'Account': 'Card',
#   'Category': 'SL',
#   'Note': None,
#   'Amount': '26',
#   'Type': 'Expense'},
#  {'Date': '2022-04-21 12:10:26',
#   'Account': 'Card',
#   'Category': 'Nordnet',
#   'Note': None,
#   'Amount': '72',
#   'Type': 'Transfer-Out'},
#  ...]

# %%
transactions = data_copy

# %%
from datetime import datetime

def transform_transaction(tx: dict) -> dict:
    # Convert the date string to a datetime object.
    dt = datetime.strptime(tx["Date"], "%Y-%m-%d %H:%M:%S")
    # Convert amount to a float and get the absolute value.
    amount = float(tx["Amount"])
    abs_amount = abs(amount)
    
    # Check if this is a transfer transaction.
    if tx["Type"].lower() == "transfer-out":
        # Map fields for a TransferTransaction.
        return {
            "dateTime": dt.isoformat(),
            "note": tx["Note"],
            "amount": abs_amount,
            "type": "transfer",
            "fromAccount": tx["Account"],
            "toAccount": tx["Category"]
        }
    else:
        # For DebitCreditTransaction, determine the new type.
        # Income: positive -> credit, negative -> debit.
        # Expense: always debit.
        if tx["Type"].lower() == "income":
            new_type = "credit" if amount >= 0 else "debit"
        elif tx["Type"].lower() == "expense":
            new_type = "debit"
        else:
            # Fallback: you can adjust this as needed.
            new_type = "debit"
        
        return {
            "dateTime": dt.isoformat(),
            "note": tx["Note"],
            "amount": abs_amount,
            "type": new_type,
            "account": tx["Account"],
            "category": tx["Category"],
            "tag": []  # Empty list for tags
        }

# %%
new_transactions = [transform_transaction(tx) for tx in transactions]

# %%
with open("transactions_transformed.json", "w") as f:
    json.dump(new_transactions, f, indent=2)
